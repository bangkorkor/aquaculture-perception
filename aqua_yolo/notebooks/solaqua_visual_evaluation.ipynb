# %% [markdown]
# # Evaluating the aquayolo models on SOLAQUA sonar videos

# %% [markdown]
# # [Fish] CFC_gray trained, solaqua cfc_style tested

# %%
from utils.evaluation_utils import annotate_images_from_folder


bag_stem = "2024-08-20_13-57-42"
sonar_frames = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/images"
out_annot    = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/predictions"

annotate_images_from_folder(
    images_dir=sonar_frames,
    out_dir=out_annot,
    weights="../runs_aquayolo/cfc_gray_adamW_m/weights/best.pt",  # <-- your trained model
    imgsz=640,
    conf=0.70,  # tweak this
    pattern="*.jpg",  # adjust if your frames are png
)
# Out:
# [INFO] Annotating 1249 images from ../../solaqua/data/exports/sonar/2024-08-20_13-57-42/cfc_style/images
# YOLO annotate: 100%|██████████| 1249/1249 [00:36<00:00, 34.19it/s]
# [DONE] Wrote annotated images to: /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/sonar/2024-08-20_13-57-42/cfc_style/predictions

# %% [markdown]
# # [Fish] CFC_gray_TINY trained, SOLAQUA cfc_style tested

# %%
from utils.evaluation_utils import annotate_images_from_folder


bag_stem = "2024-08-20_13-57-42"
sonar_frames = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/images"
out_annot    = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/predictions"

annotate_images_from_folder(
    images_dir=sonar_frames,
    out_dir=out_annot,
    weights="../runs_aquayolo/cfc_gray_tiny_adamW_m/weights/best.pt",  # <-- trained model
    imgsz=640,
    conf=0.70,  # tweak this
    pattern="*.jpg",  # adjust if your frames are png
)
# Out:
# [INFO] Annotating 1249 images from ../../solaqua/data/exports/sonar/2024-08-20_13-57-42/cfc_style/images
# YOLO annotate: 100%|██████████| 1249/1249 [00:56<00:00, 22.08it/s]
# [DONE] Wrote annotated images to: /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/sonar/2024-08-20_13-57-42/cfc_style/predictions

# %% [markdown]
# When you have run the box above you have the full annotated dataset. Now you should make a mp4 of this and see the results. Make mp4 in solaqua_sonar_dataprocessing in solaqua root-folder.

# %% [markdown]
# # [Net] net_sonar (lightaug) trained, Solaqua cfc_style tested

# %%
from utils.evaluation_utils import annotate_images_from_folder


bag_stem = "2024-08-20_17-14-36"
sonar_frames = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/images"
out_annot    = f"../../solaqua/data/exports/sonar/{bag_stem}/cfc_style/predictions"

annotate_images_from_folder(
    images_dir=sonar_frames,
    out_dir=out_annot,
    weights="../runs_aquayolo/net_sonar_SGD_1280_lightaug/weights/best.pt",  # <-- trained model
    imgsz=640,
    conf=0.40,  # tweak this
    iou=0.5,
    pattern="*.jpg",  # adjust if your frames are png
)
# Out:
# [INFO] Annotating 769 images from ../../solaqua/data/exports/sonar/2024-08-20_17-14-36/cfc_style/images
# YOLO annotate: 100%|██████████| 769/769 [00:16<00:00, 45.46it/s]
# [DONE] Wrote annotated images to: /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/sonar/2024-08-20_17-14-36/cfc_style/predictions
