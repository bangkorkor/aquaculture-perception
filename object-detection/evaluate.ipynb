# %% [markdown]
# # Evaluate models on test set
#
# This script is for evaluating the models on the test set. Remeber to change the val in the .yaml files and change the input/output paths in in this code.

# %%
# %pip install -e /cluster/home/henrban/aquaculture-perception/ultralytics
# Out:
# Obtaining file:///cluster/home/henrban/aquaculture-perception/ultralytics
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: file:///cluster/home/henrban/aquaculture-perception/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, "/cluster/home/henrban/aquaculture-perception")
import ultralytics
print(ultralytics.__file__)
# Out:
# /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
import sys, os
print("python:", sys.executable)
print("cwd:", os.getcwd())

try:
    import ultralytics
    print("ultralytics imported from:", ultralytics.__file__)
except Exception as e:
    print("ultralytics import failed:", repr(e))
# Out:
# python: /cluster/home/henrban/aquaculture-perception/.venv/bin/python
# cwd: /cluster/home/henrban/aquaculture-perception/object-detection
# ultralytics imported from: /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/uw-yolov8_ruod_120e2/weights/best.pt")
results = model.val(
    data="../data-processing/vision/RUOD/ruod.yaml",
    imgsz=640,
    batch=1,
    iou=0.7,
    plots=True,
    project="outputs/evaluation",
    name="EVAL_uw-yolov8?_ruod",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-PCIE-40GB, 40441MiB)
# uw_YOLOv8 summary: 293 layers, 35,972,654 parameters, 0 gradients, 101.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 22.1±22.1 MB/s, size: 383.4 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/vision/RUOD/processed/labels/test.cache... 4200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4200/4200 338.8Mit/s 0.0s
# /cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4200/4200 34.7it/s 2:01<0.1s
#                    all       4200      22969      0.855      0.791      0.854      0.615
#            holothurian        756       2382      0.859      0.727      0.817      0.506
#                echinus        806       3425      0.894      0.851      0.909      0.536
#                scallop        437       2373       0.83      0.718      0.816      0.515
#               starfish        780       2373       0.86      0.854      0.903      0.563
#                   fish        966       4001      0.803      0.655       0.75      0.517
#                  coral        798       2751      0.754      0.677       0.73      0.545
#                  diver        932       1997      0.904      0.895      0.933      0.727
#             cuttlefish        810       1607      0.946      0.936      0.972      0.837
#                 turtle        915       1296      0.941      0.931      0.962      0.824
#              jellyfish        325        764      0.753      0.669      0.748      0.581
# Speed: 0.7ms preprocess, 21.0ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /cluster/home/henrban/aquaculture-perception/runs/detect/outputs/evaluation/EVAL_uw-yolov8?_ruod
