# %% [markdown]
# # Evaluate models on test set
#
# This script is for evaluating the models on the test set. Remeber to change the val in the .yaml files and change the input/output paths in in this code.

# %%
# %pip install -e /cluster/home/henrban/aquaculture-perception/ultralytics
# Out:
# Obtaining file:///cluster/home/henrban/aquaculture-perception/ultralytics
# ERROR: file:///cluster/home/henrban/aquaculture-perception/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# sys.path.insert(0, "/workspace/aquaculture-perception")
# import ultralytics
# print(ultralytics.__file__)




import sys
sys.path.insert(0, "/cluster/home/henrban/aquaculture-perception")
import ultralytics
print(ultralytics.__file__)
# Out:
# /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
import sys, os
print("python:", sys.executable)
print("cwd:", os.getcwd())

try:
    import ultralytics
    print("ultralytics imported from:", ultralytics.__file__)
except Exception as e:
    print("ultralytics import failed:", repr(e))
# Out:
# python: /cluster/home/henrban/aquaculture-perception/.venv/bin/python
# cwd: /cluster/home/henrban/aquaculture-perception/object-detection
# ultralytics imported from: /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %% [markdown]
# # RUOD

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/RUOD/yolov26s_ruod_120e_fair/weights/best.pt")
results = model.val(
    data="../data-processing/vision/RUOD/ruod.yaml",
    split='test',
    imgsz=640,
    batch=1,
    iou=0.45, # nms
    conf= 0.25, # confidence threshold 

    plots=False,
    project="outputs/evaluation/RUOD",
    name="EVAL_yolov26s_ruod_120e_fair",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# YOLO26s summary (fused): 122 layers, 9,469,050 parameters, 0 gradients, 20.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 567.5±547.2 MB/s, size: 172.4 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/vision/RUOD/processed/labels/test.cache... 4200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4200/4200 880.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4200/4200 96.9it/s 43.4s<0.1ss
#                    all       4200      22969      0.881      0.678      0.793      0.607
#            holothurian        756       2382      0.892      0.556       0.73      0.492
#                echinus        806       3425      0.893      0.756      0.825      0.505
#                scallop        437       2373      0.833      0.607      0.741      0.501
# ...

# %% [markdown]
# # UATD

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/UATD/yolov26s_uatd_120e_fair/weights/best.pt")
results = model.val(
    data="../data-processing/sonar/UATD/uatd.yaml",
    split='test',
    imgsz=640,
    batch=1,
    iou=0.45, # nms
    conf= 0.25, # confidence threshold 

    plots=False,
    project="outputs/evaluation/UATD",
    name="EVAL_yolov26s_uatd_120e_fair",
    exist_ok=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # REMEMBER CHANGING OUTPUT EVAL
# ----> 3 from ultralytics import YOLO
#       7 model = YOLO("../runs/detect/outputs/training/UATD/yolov26s_uatd_120e_fair/weights/best.pt")
#       8 results = model.val(
#       9     data="../data-processing/sonar/UATD/uatd.yaml",
#      10     split='test',
#    (...)
#      19     exist_ok=True
#      20 )
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/aquaculture-perception/ultralytics/__init__.py:38, in __getattr__(name)
#      36 """Lazy-import model classes on first access."""
#      37 if name in MODELS:
# ---> 38     return getattr(importlib.import_module("ultralytics.models"), name)
#      39 raise AttributeError(f"module {__name__} has no attribute {name}")
#
# ...

# %% [markdown]
# # solaqua_fish

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/solaqua_fish/rt_detr_solaqua_fish_120e_fair/weights/best.pt")
results = model.val(
    data="../data-processing/vision/solaqua_fish/solaqua_fish.yaml",
    split='test',
    imgsz=640,
    batch=1,
    iou=0.45, # nms
    conf= 0.25, # confidence threshold 

    plots=False,
    project="outputs/evaluation/solaqua_fish",
    name="EVAL_rt_detr_solaqua_fish_120e_fair",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# rt-detr-l summary: 310 layers, 31,985,795 parameters, 0 gradients, 103.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 637.2±224.4 MB/s, size: 246.9 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/vision/solaqua_fish/processed/split_yolo/labels/test.cache... 164 images, 11 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 164/164 21.5Mit/s 0.0s
# /cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ...
