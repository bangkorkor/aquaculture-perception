# %% [markdown]
# # Evaluate models on test set
#
# This script is for evaluating the models on the test set. Remeber to change the val in the .yaml files and change the input/output paths in in this code.

# %%
# %pip install -e /cluster/home/henrban/aquaculture-perception/ultralytics
# Out:
# Obtaining file:///cluster/home/henrban/aquaculture-perception/ultralytics
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: file:///cluster/home/henrban/aquaculture-perception/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, "/cluster/home/henrban/aquaculture-perception")
import ultralytics
print(ultralytics.__file__)
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 632, in get
#     value = obj._trait_values[self.name]
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 301, in dispatch_control
#     async with self._control_lock:
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 649, in get
#     value = self._validate(obj, default)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 722, in _validate
#     value = self.validate(obj, value)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 2311, in validate
#     self.error(obj, value)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 831, in error
#     raise TraitError(e)
# traitlets.traitlets.TraitError: The '_control_lock' trait of an IPythonKernel instance expected a Lock, not the NoneType None.
# /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
import sys, os
print("python:", sys.executable)
print("cwd:", os.getcwd())

try:
    import ultralytics
    print("ultralytics imported from:", ultralytics.__file__)
except Exception as e:
    print("ultralytics import failed:", repr(e))
# Out:
# python: /cluster/home/henrban/aquaculture-perception/.venv/bin/python
# cwd: /cluster/home/henrban/aquaculture-perception/object-detection
# ultralytics imported from: /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/UATD/yolov11s_uatd_120e/weights/best.pt")
results = model.val(
    data="../data-processing/sonar/UATD/uatd.yaml",
    imgsz=640,
    batch=1,
    iou=0.7,
    plots=False,
    project="outputs/evaluation/UATD",
    name="EVAL_yolov11s_uatd",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-PCIE-40GB, 40441MiB)
# YOLO11s summary (fused): 101 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3680.6±261.4 MB/s, size: 4309.3 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/sonar/UATD/processed/labels/test.cache... 798 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 798/798 111.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 798/798 92.5it/s 8.6s0.0s
#                    all        798       1154      0.878      0.822      0.873      0.407
#             human-body         73         73      0.799      0.945      0.884      0.385
#                   ball        193        193      0.843      0.886      0.882      0.454
#            circle-cage         99         99      0.848      0.424      0.664      0.315
#            square-cage        168        168      0.861      0.649       0.67       0.23
#                   tyre        120        120      0.976       0.68      0.893      0.484
#           metal-bucket          5          5      0.974          1      0.995      0.379
#                   cube        166        166      0.699      0.904      0.873      0.317
#               cylinder         45         45      0.791      0.933      0.899      0.382
#                  plane        135        135      0.984      0.922      0.982      0.634
#                    rov        150        150          1      0.877      0.988      0.493
# Speed: 0.6ms preprocess, 7.1ms inference, 0.0ms loss, 0.8ms postprocess per image
