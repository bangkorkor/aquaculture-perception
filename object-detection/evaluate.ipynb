# %% [markdown]
# # Evaluate models on test set
#
# This script is for evaluating the models on the test set. Remeber to change the val in the .yaml files and change the input/output paths in in this code.

# %%
# %pip install -e /cluster/home/henrban/aquaculture-perception/ultralytics
# Out:
# Obtaining file:///cluster/home/henrban/aquaculture-perception/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (3.9.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (0.23.0)
# Requirement already satisfied: psutil in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (7.1.0)
# Requirement already satisfied: polars in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (1.34.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from ultralytics==8.3.213) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.213) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics==8.3.213) (3.23.0)
# Requirement already satisfied: six>=1.5 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.213) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.3.213) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.3.213) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.3.213) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.3.213) (2025.10.5)
# Requirement already satisfied: filelock in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (1.14.0)
# Requirement already satisfied: networkx in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (3.2.1)
# Requirement already satisfied: jinja2 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (3.1.6)
# Requirement already satisfied: fsspec in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.3.213) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics==8.3.213) (53.0.0)
# Requirement already satisfied: importlib-metadata in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics==8.3.213) (8.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.3.213) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.213) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /cluster/home/henrban/aquaculture-perception/.venv/lib/python3.9/site-packages (from polars->ultralytics==8.3.213) (1.34.0)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.213-0.editable-py3-none-any.whl size=23181 sha256=500213db44cea7bf6d9c8edeb6c64e4a149e731009078f0bff90404020b55479
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0mthc65f/wheels/7e/54/2f/a48fdd760435dc71e33a477e6b608c7eda6c25e93e0302a102
# Successfully built ultralytics
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.213
#     Uninstalling ultralytics-8.3.213:
#       Successfully uninstalled ultralytics-8.3.213
# Successfully installed ultralytics-8.3.213
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
print("python:", sys.executable)
print("cwd:", os.getcwd())

try:
    import ultralytics
    print("ultralytics imported from:", ultralytics.__file__)
except Exception as e:
    print("ultralytics import failed:", repr(e))
# Out:
# python: /cluster/home/henrban/aquaculture-perception/.venv/bin/python
# cwd: /cluster/home/henrban/aquaculture-perception/object-detection
# ultralytics import failed: ModuleNotFoundError("No module named 'ultralytics'")

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO

model = YOLO("outputs/training/AGW_YOLOv8s_RUOD/weights/best.pt")
results = model.val(
    data="../data-processing/vision/RUOD/ruod.yaml",
    imgsz=640,
    batch=1,
    iou=0.7,
    plots=True,
    project="outputs/evaluation",
    name="EVAL_agw_yolov8s_ruod",
    exist_ok=True
)
# Out:
# Ultralytics 8.3.213 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# agw_YOLOv8 summary: 206 layers, 32,562,492 parameters, 0 gradients, 83.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 962.3±621.4 MB/s, size: 119.2 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/vision/RUOD/processed/labels/test.cache... 4200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4200/4200 5.9Mit/s 0.0s0s
# /cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4200/4200 59.3it/s 1:11<0.1ss
#                    all       4200      22969      0.871      0.792      0.859       0.64
#            holothurian        756       2382      0.859      0.743      0.818      0.533
#                echinus        806       3425      0.892       0.85      0.906      0.551
#                scallop        437       2373      0.855      0.741      0.832      0.545
#               starfish        780       2373      0.878       0.85      0.901      0.576
#                   fish        966       4001       0.82      0.641      0.753      0.533
#                  coral        798       2751      0.776      0.671      0.741      0.578
#                  diver        932       1997      0.923      0.894       0.94      0.762
#             cuttlefish        810       1607      0.953      0.932       0.97      0.861
#                 turtle        915       1296      0.948      0.938      0.967      0.857
#              jellyfish        325        764      0.804      0.665      0.763      0.607
# Speed: 0.5ms preprocess, 10.9ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /cluster/home/henrban/aquaculture-perception/object-detection/outputs/evaluation/EVAL_agw_yolov8s_ruod
