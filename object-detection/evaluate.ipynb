# %% [markdown]
# # Evaluate models on test set
#
# This script is for evaluating the models on the test set. Remeber to change the val in the .yaml files and change the input/output paths in in this code.

# %%
# %pip install -e /cluster/home/henrban/aquaculture-perception/ultralytics
# Out:
# Obtaining file:///cluster/home/henrban/aquaculture-perception/ultralytics
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: file:///cluster/home/henrban/aquaculture-perception/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, "/cluster/home/henrban/aquaculture-perception")
import ultralytics
print(ultralytics.__file__)
# Out:
# /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
import sys, os
print("python:", sys.executable)
print("cwd:", os.getcwd())

try:
    import ultralytics
    print("ultralytics imported from:", ultralytics.__file__)
except Exception as e:
    print("ultralytics import failed:", repr(e))
# Out:
# python: /cluster/home/henrban/aquaculture-perception/.venv/bin/python
# cwd: /cluster/home/henrban/aquaculture-perception/object-detection
# ultralytics imported from: /cluster/home/henrban/aquaculture-perception/ultralytics/__init__.py

# %%
# REMEMBER CHANGING OUTPUT EVAL

from ultralytics import YOLO



model = YOLO("../runs/detect/outputs/training/yolov8m_ruod/weights/best.pt")
results = model.val(
    data="../data-processing/vision/RUOD/ruod.yaml",
    imgsz=640,
    batch=1,
    iou=0.7,
    plots=True,
    project="outputs/evaluation",
    name="EVAL_yolov8m_ruod",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.9.21 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-PCIE-40GB, 40441MiB)
# Model summary (fused): 93 layers, 25,845,550 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 10.0±6.3 MB/s, size: 137.4 KB)
# val: Scanning /cluster/home/henrban/aquaculture-perception/data-processing/vision/RUOD/processed/labels/test.cache... 4200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4200/4200 476.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4200/4200 51.3it/s 1:22<0.1ss
#                    all       4200      22969      0.868      0.814      0.868      0.656
#            holothurian        756       2382      0.857      0.754      0.827      0.538
#                echinus        806       3425      0.889      0.861      0.909      0.561
#                scallop        437       2373      0.845      0.769       0.84      0.549
#               starfish        780       2373      0.869      0.853        0.9      0.585
#                   fish        966       4001      0.802      0.695      0.788      0.575
#                  coral        798       2751      0.766      0.692      0.741      0.576
#                  diver        932       1997      0.924       0.91       0.95       0.79
#             cuttlefish        810       1607      0.965      0.948      0.975      0.883
#                 turtle        915       1296      0.969      0.951      0.975      0.881
#              jellyfish        325        764       0.79      0.711      0.772      0.619
# Speed: 0.6ms preprocess, 12.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /cluster/home/henrban/aquaculture-perception/runs/detect/outputs/evaluation/EVAL_yolov8m_ruod
