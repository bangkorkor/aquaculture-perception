# %% [markdown]
# # Showing Video Results
#
#
# Now we have the sonar images (with or without predictions) and the vision images (with or withcout predictions).
# We want to time is so that we can make a new video that syncs the images side by side and shows it.

# %% [markdown]
# ## Showng side by side VISION and SONAR
#
# **TODO**: show information in the film about what ns we are on etc.

# %%
import os
os.environ["PATH"] = "/cluster/home/henrban/.conda/envs/myffmpeg/bin:" + os.environ["PATH"]
# !ffmpeg -version
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
# built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
# configuration: --prefix=/cluster/home/henrban/.conda/envs/myffmpeg --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/pkg-config
# libavutil      60.  8.100 / 60.  8.100
# libavcodec     62. 11.100 / 62. 11.100
# libavformat    62.  3.100 / 62.  3.100
# libavdevice    62.  1.100 / 62.  1.100
# libavfilter    11.  4.100 / 11.  4.100
# libswscale      9.  1.100 /  9.  1.100
# libswresample   6.  1.100 /  6.  1.100
#
# Exiting with exit code 0

# %%
from pathlib import Path
from utils.sonar_visualization import side_by_side_vfr_from_folders


bag_stem = "2024-08-20_13-57-42"

vision_dir = Path(f"data/exports/vision/{bag_stem}/raw/image__compressed_image__data")
sonar_dir  = Path(f"data/exports/sonar/{bag_stem}/cfc_style/images")
out_mp4    = Path(f"data/exports/combined_results/{bag_stem}_sbs_raw_cfc_gray.mp4")

side_by_side_vfr_from_folders(vision_dir, sonar_dir, out_mp4, out_height=720, crf=18, preset="slow")
# Out:
# Running: ffmpeg -y -f concat -safe 0 -i /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.vision.list.txt -f concat -safe 0 -i /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.sonar.list.txt -fps_mode vfr -filter_complex [0:v]null,scale=-2:720[v0];[1:v]tpad=start_duration=0.0918881893157959:start_mode=clone,scale=-2:720[v1];[v0][v1]hstack=inputs=2:shortest=1[v] -map [v] -pix_fmt yuv420p -c:v libx264 -crf 18 -preset slow -movflags +faststart /cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.mp4
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
#   configuration: --prefix=/cluster/home/henrban/.conda/envs/myffmpeg --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, concat, from '/cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.vision.list.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 fps, 25 tbr, 25 tbn
# Input #1, concat, from '/cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.sonar.list.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #1:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1200x700 [SAR 1:1 DAR 12:7], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 (mjpeg) -> null:default
#   Stream #1:0 (mjpeg) -> tpad:default
#   hstack:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [swscaler @ 0x148030099100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x1480301f2280] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5605a7f81fc0] using SAR=1/1
# [libx264 @ 0x5605a7f81fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5605a7f81fc0] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x5605a7f81fc0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/cluster/home/henrban/SOLAQUA-UOD/solaqua/data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(pc, bt470bg/unknown/unknown, progressive), 2514x720 [SAR 1:1 DAR 419:120], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1979 fps= 44 q=-1.0 size=  159488KiB time=00:01:19.08 bitrate=16521.6kbits/s dup=0 drop=7 speed=1.76x elapsed=0:00:45.00
# ✅ Wrote side-by-side: data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.mp4
# [mp4 @ 0x5605a7f7f880] Starting second pass: moving the moov atom to the beginning of the file
# [out#0/mp4 @ 0x5605a7eb5600] video:161109KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.015950%
# frame= 1999 fps= 44 q=-1.0 Lsize=  161134KiB time=00:01:19.88 bitrate=16524.9kbits/s dup=0 drop=7 speed=1.76x elapsed=0:00:45.41
# [libx264 @ 0x5605a7f81fc0] frame I:11    Avg QP:14.14  size:306683
# [libx264 @ 0x5605a7f81fc0] frame P:603   Avg QP:18.67  size:162951
# [libx264 @ 0x5605a7f81fc0] frame B:1385  Avg QP:21.39  size: 45734
# [libx264 @ 0x5605a7f81fc0] consecutive B-frames:  3.5%  8.6% 11.3% 76.6%
# [libx264 @ 0x5605a7f81fc0] mb I  I16..4: 17.8% 76.2%  6.0%
# [libx264 @ 0x5605a7f81fc0] mb P  I16..4:  0.3% 17.6%  1.6%  P16..4: 25.1% 21.3% 12.2%  0.0%  0.0%    skip:21.9%
# [libx264 @ 0x5605a7f81fc0] mb B  I16..4:  0.0%  3.8%  1.0%  B16..8: 22.4%  6.7%  3.6%  direct: 8.6%  skip:53.9%  L0:44.0% L1:29.7% BI:26.4%
# [libx264 @ 0x5605a7f81fc0] 8x8 transform intra:85.5% inter:64.1%
# [libx264 @ 0x5605a7f81fc0] direct mvs  spatial:99.3% temporal:0.7%
# [libx264 @ 0x5605a7f81fc0] coded y,uvDC,uvAC intra: 95.8% 10.8% 10.1% inter: 31.8% 34.9% 26.7%
# [libx264 @ 0x5605a7f81fc0] i16 v,h,dc,p: 72% 10%  9%  9%
# [libx264 @ 0x5605a7f81fc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 13% 12%  8% 12%  6% 18%  7% 18%
# [libx264 @ 0x5605a7f81fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  4% 12%  8%  7% 17%  7% 25%  6% 15%
# [libx264 @ 0x5605a7f81fc0] i8c dc,h,v,p: 94%  3%  2%  1%
# [libx264 @ 0x5605a7f81fc0] Weighted P-Frames: Y:2.5% UV:1.3%
# [libx264 @ 0x5605a7f81fc0] ref P L0: 43.8% 13.1% 30.3%  5.8%  6.5%  0.4%  0.0%
# [libx264 @ 0x5605a7f81fc0] ref B L0: 77.1% 12.5%  7.1%  3.3%
# [libx264 @ 0x5605a7f81fc0] ref B L1: 98.2%  1.8%
# [libx264 @ 0x5605a7f81fc0] kb/s:16505.71
# PosixPath('data/exports/combined_results/2024-08-20_13-57-42_sbs_raw_cfc_gray.mp4')
