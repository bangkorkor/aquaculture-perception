# %% [markdown]
# # Dataset Extraction
#
# This is a notebook for getting started with the data. With raw (raw_processed) i mean that no detector or further processing has been done to the image, its just the extracted frames from the bag files.
#
# The dataset used is **SOLAQUA**, available from [SINTEF Open Data](https://data.sintef.no/feature/fe-a8f86232-5107-495e-a3dd-a86460eebef6).

# %% [markdown]
# ## Installing Packages

# %%
from collections import defaultdict 
from rosbags.highlevel import AnyReader
from pathlib import Path
import numpy as np
import cv2
import re
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 632, in get
#     value = obj._trait_values[self.name]
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 301, in dispatch_control
#     async with self._control_lock:
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 649, in get
#     value = self._validate(obj, default)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 722, in _validate
#     value = self.validate(obj, value)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 2311, in validate
#     self.error(obj, value)
#   File "/cluster/home/henrban/aquaculture-perception/.venv/lib64/python3.9/site-packages/traitlets/traitlets.py", line 831, in error
#     raise TraitError(e)
# traitlets.traitlets.TraitError: The '_control_lock' trait of an IPythonKernel instance expected a Lock, not the NoneType None.

# %% [markdown]
# ## Defining .bag files
#
# All bags should be placed in the `solaqua-bags` folder.
#
# - `*_data.bag` → contains **sensor data** (ROS bag format).
# - `*_video.bag` → contains **video images** (ROS bag format).
#
# The dataset used is **SOLAQUA**, available from [SINTEF Open Data](https://data.sintef.no/feature/fe-a8f86232-5107-495e-a3dd-a86460eebef6).

# %%
# Change these two lines to switch dataset
TIMESTAMP = '2024-08-20_14-31-29' # change here!


DATA_BAG  = Path("../../solaqua_bags/" + TIMESTAMP+ "_data.bag")   # sensor data
VIDEO_BAG = Path("../../solaqua_bags/" + TIMESTAMP+ "_video.bag")  # camera and sonar video

# Output folder for extracted frames, videos, sonar arrays, etc.
OUT_ROOT = Path("raw_processed")
OUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Using data bag : {DATA_BAG.resolve()}")
print(f"Using video bag: {VIDEO_BAG.resolve()}")
print(f"Output folder : {OUT_ROOT.resolve()}")
# Out:
# Using data bag : /cluster/home/henrban/aquaculture-perception/data-processing/solaqua_bags/2024-08-20_14-31-29_data.bag
# Using video bag: /cluster/home/henrban/aquaculture-perception/data-processing/solaqua_bags/2024-08-20_14-31-29_video.bag
# Output folder : /cluster/home/henrban/aquaculture-perception/data-processing/vision/SOLAQUA/raw_processed

# %% [markdown]
# ## List Topics

# %%
def human_hz(count, duration_s):
    if count == 0 or duration_s <= 0:
        return 0.0
    return count / duration_s

for bag in [DATA_BAG, VIDEO_BAG]:
    print(f"\n=== {bag.name} ===")
    if not bag.exists():
        print("  (missing)")
        continue

    counts = defaultdict(int)
    first_ts = defaultdict(lambda: None)
    last_ts  = defaultdict(lambda: None)
    types = {}

    with AnyReader([bag]) as r:
        for c in r.connections:
            types[c.topic] = c.msgtype
        for conn, ts, _ in r.messages():
            t = conn.topic
            counts[t] += 1
            if first_ts[t] is None or ts < first_ts[t]:
                first_ts[t] = ts
            if last_ts[t] is None or ts > last_ts[t]:
                last_ts[t] = ts

    if not counts:
        print("  (no messages)")
        continue

    col_topic = max(len(t) for t in counts.keys())
    col_type  = max(len(types.get(t, "")) for t in counts.keys())
    header = f"{'TOPIC'.ljust(col_topic)}  {'TYPE'.ljust(col_type)}  COUNT    START(ns)          END(ns)            DURATION(s)  ~HZ"
    print(header)
    print("-" * len(header))

    for t in sorted(counts.keys()):
        n = counts[t]
        t0 = first_ts[t]
        t1 = last_ts[t]
        dur_s = (t1 - t0) / 1e9 if (t0 is not None and t1 is not None) else 0.0
        hz = human_hz(n, dur_s)
        print(
            f"{t.ljust(col_topic)}  "
            f"{types.get(t,'').ljust(col_type)}  "
            f"{str(n).rjust(5)}    "
            f"{str(t0).rjust(16)}  "
            f"{str(t1).rjust(16)}  "
            f"{dur_s:11.3f}  {hz:5.2f}"
        )
# Out:
# === 2024-08-20_14-31-29_data.bag ===
# TOPIC                                     TYPE                                     COUNT    START(ns)          END(ns)            DURATION(s)  ~HZ
# --------------------------------------------------------------------------------------------------------------------------------------------------
# /bluerov2/alive                           std_msgs/msg/Float32                       129    1724157094493788400  1724157158270660900       63.777   2.02
# /bluerov2/armed                           std_msgs/msg/Float32                       131    1724157093740108300  1724157158270716300       64.531   2.03
# /bluerov2/battery                         messages/msg/BatteryStatus                  60    1724157095568144200  1724157158350797800       62.783   0.96
# /bluerov2/modes                           joystick/msg/ModeManager2                    1    1724157091929707100  1724157091929707100        0.000   0.00
# /commanded_thrust                         rospy_tutorials/msg/Floats                1329    1724157092172524500  1724157158575045100       66.403  20.01
# /controller/x                             messages/msg/MRACOupdate                   538    1724157095767257700  1724157158562705100       62.795   8.57
# /controller/y                             messages/msg/MRACOupdate                   536    1724157096159198600  1724157158561497400       62.402   8.59
# /controller/yaw                           messages/msg/PIDState                      534    1724157096560956500  1724157158559344000       61.998   8.61
# /controller/z                             messages/msg/PIDState                      543    1724157094837299800  1724157158559195000       63.722   8.52
# /gui/netFollowing_manager                 messages/msg/NetFollowingManager            64    1724157094923986700  1724157157919857200       62.996   1.02
# /guidance                                 messages/msg/GuidanceManager               549    1724157093499372300  1724157158558704200       65.059   8.44
# /joystick                                 joystick/msg/Joystick                     1251    1724157096099852200  1724157158600269000       62.500  20.02
# /joystick/init                            std_msgs/msg/Float32                         1    1724157095772063500  1724157095772063500        0.000   0.00
# /navigation/plane_approximation           messages/msg/PlaneApproximation            559    1724157091549889800  1724157158557894000       67.008   8.34
# /navigation/plane_approximation_position  messages/msg/PlaneApproximationPosition    278    1724157095039539800  1724157158369751600       63.330   4.39
# /rosout                                   rosgraph_msgs/msg/Log                       32    1724157091198592000  1724157158602249000       67.404   0.47
# /rosout_agg                               rosgraph_msgs/msg/Log                        1    1724157158602773100  1724157158602773100        0.000   0.00
# /sensor/attitude                          messages/msg/Attitude                     1004    1724157095049293000  1724157158558620200       63.509  15.81
# /sensor/depth_temperature                 messages/msg/DepthTemperature              943    1724157095201495300  1724157158572236800       63.371  14.88
# /sensor/dvl_position                      sensors/msg/DVLPosition                    283    1724157093310282800  1724157158369435000       65.059   4.35
# /sensor/dvl_velocity                      sensors/msg/DVLVelocity                    545    1724157094427458100  1724157158555980700       64.129   8.50
# /sensor/imu                               messages/msg/IMU                          1001    1724157095482836400  1724157158600133100       63.117  15.86
# /sensor/ping360                           sensors/msg/Ping360                        499    1724157095298927100  1724157156418388200       61.119   8.16
# /sensor/ping360_config                    sensors/msg/Ping360_config_2                 1    1724157096198104200  1724157096198104200        0.000   0.00
# /sensor/usbl                              sensors/msg/SonardyneUSBL2                  33    1724157093805148300  1724157157147113600       63.342   0.52
#
# === 2024-08-20_14-31-29_video.bag ===
# TOPIC                                TYPE                             COUNT    START(ns)          END(ns)            DURATION(s)  ~HZ
# -------------------------------------------------------------------------------------------------------------------------------------
# /image/compressed_image/camera_info  sensor_msgs/msg/CameraInfo           1    1724157091611805000  1724157091611805000        0.000   0.00
# /image/compressed_image/data         sensor_msgs/msg/CompressedImage   1688    1724157091855545200  1724157159332278000       67.477  25.02
# /sensor/sonoptix_echo/image          sensors/msg/SonoptixECHO          1060    1724157091569867200  1724157159364494200       67.795  15.64
# /ted/image                           sensor_msgs/msg/CompressedImage   1691    1724157091738650100  1724157159341000600       67.602  25.01

# %% [markdown]
# ## Extracting data

# %% [markdown]
# ### making frames

# %%
from pathlib import Path
import numpy as np
import cv2



from contextlib import ExitStack


# --- Config ---
# Set to None to include all image topics
# Or use a set like {"/image/compressed_image/data"} to include only specific topics
TOPIC_INCLUDE = {"/image/compressed_image/data"}

# Exclude topics here if needed
TOPIC_EXCLUDE = set()   # e.g. {"/image/compressed_image/camera_info"}


# --- Output scaffolding ---
bag_stem = VIDEO_BAG.stem.replace("_video", "")
RUN_ROOT = OUT_ROOT / "all_images" / bag_stem
RUN_ROOT.mkdir(parents=True, exist_ok=True)

assert VIDEO_BAG.exists(), f"Missing video bag: {VIDEO_BAG}"

print(f"[INFO] Reading {VIDEO_BAG.name}")
print(f"[INFO] Saving frames under: {RUN_ROOT}")


def sanitize_topic(topic: str) -> str:
    """Make a filesystem-safe topic label."""
    base = topic.strip("/")
    safe = base.replace("/", "__")
    safe = "".join(ch if (ch.isalnum() or ch in "_-.") else "_" for ch in safe)
    return safe or "topic"


def decode_raw_image(msg):
    """Decode sensor_msgs/msg/Image to BGR np.ndarray (uint8)."""
    h, w, step = msg.height, msg.width, msg.step
    enc = (msg.encoding or "").lower()
    buf = np.frombuffer(msg.data, dtype=np.uint8)

    # Common 8-bit encodings
    if enc == "bgr8":
        frame = buf.reshape(h, step)[:, : w * 3].reshape(h, w, 3)
        return frame

    if enc == "rgb8":
        frame = buf.reshape(h, step)[:, : w * 3].reshape(h, w, 3)
        return cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)

    if enc in ("mono8", "8uc1", "8uc1c1", "mono"):
        frame = buf.reshape(h, step)[:, :w]
        return cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)

    if enc in ("yuv422", "yuyv", "yuyv422", "yuv422_yuy2"):
        frame = buf.reshape(h, step)[:, : w * 2]
        return cv2.cvtColor(frame, cv2.COLOR_YUV2BGR_YUY2)

    # Fallback heuristic
    chans = 3 if (step % w != 0) else max(1, step // w)
    try:
        raw = buf.reshape(h, step)[:, : w * chans].reshape(h, w, chans)
    except Exception:
        return None

    if chans == 1:
        return cv2.cvtColor(raw, cv2.COLOR_GRAY2BGR)

    if enc == "rgb8":
        return cv2.cvtColor(raw, cv2.COLOR_RGB2BGR)

    return raw


def save_frame(out_dir: Path, ts_ns: int, frame_bgr: np.ndarray):
    """
    Save directly under RUN_ROOT:
        <RUN_ROOT>/<timestamp>.jpg

    If you later include multiple topics and want to avoid possible filename
    collisions, switch to:
        out = out_dir / f"{sanitize_topic(topic)}__{ts_ns}.jpg"
    """
    out = out_dir / f"{ts_ns}.jpg"
    cv2.imwrite(str(out), frame_bgr)


# --- Main read loop ---
saved_by_topic = {}
skipped_by_topic = {}

with ExitStack() as stack:
    r = stack.enter_context(AnyReader([VIDEO_BAG]))

    for i, (conn, ts, raw) in enumerate(r.messages()):
        msgtype = conn.msgtype
        topic = conn.topic

        # Only image topics
        if msgtype not in ("sensor_msgs/msg/CompressedImage", "sensor_msgs/msg/Image"):
            continue

        # Topic filtering
        if TOPIC_INCLUDE is not None and topic not in TOPIC_INCLUDE:
            continue
        if topic in TOPIC_EXCLUDE:
            continue

        # Decode frame
        if msgtype == "sensor_msgs/msg/CompressedImage":
            msg = r.deserialize(raw, msgtype)
            arr = np.frombuffer(msg.data, np.uint8)
            frame = cv2.imdecode(arr, cv2.IMREAD_COLOR)
        else:
            msg = r.deserialize(raw, msgtype)
            frame = decode_raw_image(msg)

        # Bookkeeping
        if topic not in saved_by_topic:
            saved_by_topic[topic] = 0
            skipped_by_topic[topic] = 0
            print(f"[INFO] → Topic '{topic}'")

        if frame is None:
            skipped_by_topic[topic] += 1
            continue

        # Save directly into RUN_ROOT (no per-topic subfolder)
        save_frame(RUN_ROOT, ts, frame)
        saved_by_topic[topic] += 1

        if saved_by_topic[topic] % 100 == 0:
            print(f"[INFO] [{topic}] Saved {saved_by_topic[topic]} frames ...")


# --- Summary ---
print("\n[DONE] Results:")
total_saved = 0
total_skipped = 0

for t in sorted(saved_by_topic.keys()):
    s = saved_by_topic[t]
    k = skipped_by_topic.get(t, 0)
    total_saved += s
    total_skipped += k
    print(f"  - {t} → saved: {s:5d}, skipped: {k:5d}, dir: {RUN_ROOT}")

print(f"\n[TOTAL] Saved {total_saved} frames across {len(saved_by_topic)} topics.")
if total_skipped:
    print(f"[WARN] Skipped {total_skipped} frames (decode failures).")
# Out:
# [INFO] Reading 2024-08-20_16-43-25_video.bag
# [INFO] Saving frames under: raw_processed/all_images/2024-08-20_16-43-25
# [INFO] → Topic '/image/compressed_image/data'
# [INFO] [/image/compressed_image/data] Saved 100 frames ...
# [INFO] [/image/compressed_image/data] Saved 200 frames ...
# [INFO] [/image/compressed_image/data] Saved 300 frames ...
# [INFO] [/image/compressed_image/data] Saved 400 frames ...
# [INFO] [/image/compressed_image/data] Saved 500 frames ...
# [INFO] [/image/compressed_image/data] Saved 600 frames ...
# [INFO] [/image/compressed_image/data] Saved 700 frames ...
# [INFO] [/image/compressed_image/data] Saved 800 frames ...
# [INFO] [/image/compressed_image/data] Saved 900 frames ...
# [INFO] [/image/compressed_image/data] Saved 1000 frames ...
# [INFO] [/image/compressed_image/data] Saved 1100 frames ...
# [INFO] [/image/compressed_image/data] Saved 1200 frames ...
# [INFO] [/image/compressed_image/data] Saved 1300 frames ...
# [INFO] [/image/compressed_image/data] Saved 1400 frames ...
# [INFO] [/image/compressed_image/data] Saved 1500 frames ...
# [INFO] [/image/compressed_image/data] Saved 1600 frames ...
# [INFO] [/image/compressed_image/data] Saved 1700 frames ...
#
# [DONE] Results:
#   - /image/compressed_image/data → saved:  1723, skipped:     0, dir: raw_processed/all_images/2024-08-20_16-43-25
#
# [TOTAL] Saved 1723 frames across 1 topics.

# %% [markdown]
# ### Make MP4 from images

# %% [markdown]
# We are using Variable frame rate (VFR) and the ffmpeg library.
#
# Was a bit tricky to get the ffmpeg dependency. I did module load Anaconda3/2024.02-1, then conda --version to confirm. Then conda create -n myffmpeg -c conda-forge ffmpeg -y to install ffmpeg. conda activate myffmpeg and ffmpeg -version to confirm. To load it into the .venv i did: source .venv/bin/activate and then export PATH="$HOME/.conda/envs/myffmpeg/bin:$PATH". Lastly select kernel with the python enviornment (.venv).
#
# To activate environments next time do:
# - module load Anaconda3/2024.02-1
# - source .venv/bin/activate
# - export PATH="$HOME/.conda/envs/myffmpeg/bin:$PATH"
# - select right kernel
#
# - if kernel cant find ffmpeg, do this inside notebook:
# ```python
#
# ```

# %%
import os
os.environ["PATH"] = "/cluster/home/henrban/.conda/envs/myffmpeg/bin:" + os.environ["PATH"]
# !ffmpeg -version
# Out:
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
# built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
# configuration: --prefix=/cluster/home/henrban/.conda/envs/myffmpeg --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/pkg-config
# libavutil      60.  8.100 / 60.  8.100
# libavcodec     62. 11.100 / 62. 11.100
# libavformat    62.  3.100 / 62.  3.100
# libavdevice    62.  1.100 / 62.  1.100
# libavfilter    11.  4.100 / 11.  4.100
# libswscale      9.  1.100 /  9.  1.100
# libswresample   6.  1.100 /  6.  1.100
#
# Exiting with exit code 0

# %%
from utils.sonar_visualization import build_vfr_mp4_from_ns_frames


#VIDEO_BAG = Path("data/bags/2024-08-20_13-57-42_video.bag")     # bag should be defined in the top
bag_stem  = VIDEO_BAG.stem.replace("_video", "")
vision_frames = Path(f"raw_processed/all_images/{bag_stem}")
vision_out    = Path(f"raw_processed/mp4s/vision_raw_{bag_stem}.mp4")   ## change output name if you want to

build_vfr_mp4_from_ns_frames(vision_frames, vision_out, crf=18, preset="slow")
# Out:
# Running: ffmpeg -y -f concat -safe 0 -i raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.list.txt -fps_mode vfr -pix_fmt yuv420p -c:v libx264 -crf 18 -preset slow -movflags +faststart raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.mp4
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
#   configuration: --prefix=/cluster/home/henrban/.conda/envs/myffmpeg --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1758923993009/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, concat, from 'raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.list.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x14dea8085b40] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x559caefaa940] using SAR=1/1
# [libx264 @ 0x559caefaa940] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559caefaa940] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x559caefaa940] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(pc, bt470bg/unknown/unknown, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [mp4 @ 0x559caefa3500] Starting second pass: moving the moov atom to the beginning of the file elapsed=0:00:44.02
# ✅ Wrote raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.mp4
# 🧹 Deleted temporary file: vision_raw_2024-08-20_16-43-25.list.txt
# [out#0/mp4 @ 0x559caefa33c0] video:57872KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.035912%
# frame= 1724 fps= 37 q=-1.0 Lsize=   57893KiB time=00:01:08.92 bitrate=6881.3kbits/s speed=1.47x elapsed=0:00:46.95
# [libx264 @ 0x559caefaa940] frame I:9     Avg QP:15.73  size:173246
# [libx264 @ 0x559caefaa940] frame P:575   Avg QP:18.59  size: 75704
# [libx264 @ 0x559caefaa940] frame B:1140  Avg QP:21.83  size: 12431
# [libx264 @ 0x559caefaa940] consecutive B-frames:  4.4% 15.9% 19.7% 60.1%
# [libx264 @ 0x559caefaa940] mb I  I16..4:  0.6% 96.4%  3.0%
# [libx264 @ 0x559caefaa940] mb P  I16..4:  0.1%  6.1%  0.4%  P16..4: 44.5% 32.1% 15.1%  0.0%  0.0%    skip: 1.6%
# [libx264 @ 0x559caefaa940] mb B  I16..4:  0.0%  0.4%  0.0%  B16..8: 35.7%  4.6%  1.1%  direct:15.1%  skip:43.1%  L0:38.5% L1:36.3% BI:25.2%
# [libx264 @ 0x559caefaa940] 8x8 transform intra:91.4% inter:57.7%
# [libx264 @ 0x559caefaa940] direct mvs  spatial:99.5% temporal:0.5%
# [libx264 @ 0x559caefaa940] coded y,uvDC,uvAC intra: 94.5% 99.4% 92.8% inter: 38.7% 62.0% 40.7%
# [libx264 @ 0x559caefaa940] i16 v,h,dc,p:  6% 32%  9% 53%
# [libx264 @ 0x559caefaa940] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 25% 11%  6%  7%  6% 14%  7% 16%
# [libx264 @ 0x559caefaa940] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 16%  6%  7% 12%  9% 18%  8% 17%
# [libx264 @ 0x559caefaa940] i8c dc,h,v,p: 39% 40% 11% 10%
# [libx264 @ 0x559caefaa940] Weighted P-Frames: Y:12.0% UV:4.7%
# [libx264 @ 0x559caefaa940] ref P L0: 53.3% 23.7% 16.8%  3.7%  2.1%  0.4%  0.0%
# [libx264 @ 0x559caefaa940] ref B L0: 96.4%  3.0%  0.4%  0.2%
# [libx264 @ 0x559caefaa940] ref B L1: 99.7%  0.3%
# [libx264 @ 0x559caefaa940] kb/s:6870.81
# PosixPath('raw_processed/mp4s/vision_raw_2024-08-20_16-43-25.mp4')
